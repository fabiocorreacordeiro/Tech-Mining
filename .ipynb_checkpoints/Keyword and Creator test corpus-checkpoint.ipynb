# %% [markdown]
# Importando bliotecas

# %%
import pandas as pd
import random

# %% [markdown]
# Lendo arquivos

# %%
keywords = pd.read_json("Elsevier_abstract - Keywords.json")
creator = pd.read_json("Elsevier_abstract - Creators.json")
abstracts = pd.read_json("Elsevier_abstract - Preprocessado.json")

# %% [markdown]
# ### Base de teste de Keywords

# %% [markdown]
# A base de teste será composta por três colunas. As duas primeiras são de keywords que ocorrem em conjunto em um mesmo artigo, a terceira coluna conterá uma keyword aleatória. Espera-se que o vetor da keyword da primeira coluna esteja mais próximo da keyword da segunda coluna do que da terceira.

# %%
n_article = len(abstracts)
keywords_list = keywords["Keywords"].tolist() # Lista de Keywords

# Criando um DataFrame para receber os pares de keywords que aparecem no mesmo artigo
# e a keyword aleatória
test_corpus_keyword = pd.DataFrame(columns=["Keyword_1", "Keyword_2", "Random_keyword"])

for article in abstracts.iterrows():  # Iterando sobre todos os artigos
   
    words = article[1]["Keywords"]    # Célula do Dataframe onde se encontram as keywords
    if words == []:                   # Se não houver keyword passa para próximo artigo
        pass
    
    else:
        for n in range(len(words)):   # Iterando sobre todos as keywords de um artigo
            word_1 = words[n]         # Identificando primeira keyword
            # Como nem todas as keywords estão na Lista de Keywords é necessário 
            # verificar se word_1 está em keyword_list 
            if word_1 in keywords_list:
                
                for m in range(n+1, len(words)): # Iterando sobre as demais keywords
                    word_2 = words[m] # Identificando segunda keyword
                    if word_2 in keywords_list:
                        # Identificando keyword aleatória
                        random_word = random.sample(keywords_list, 1)[0]
                        # Adicionando as três keywords no dataframe "test_corpus"
                        test_corpus_keyword.loc[len(test_corpus_keyword)]= [word_1,
                                                                            word_2,
                                                                            random_word]

# %%
test_corpus_keyword.to_csv("Test_Corpus_keywords.csv")

# %%
test_corpus_keyword
# Out:
#                   Keyword_1              Keyword_2              Random_keyword
# 0                  zeolites             adsorption                 asphaltenes
# 1                diagenesis              petroleum                         mea
# 2                      coal           gasification                     alkanes
# 3                      coal              catalysis                 experiments
# 4              gasification              catalysis                    rheology
# 5                 oxidation              catalysis                         oil
# 6                 oxidation                 oxygen                   interface
# 7                 catalysis                 oxygen             process control
# 8            carbon dioxide                  model                      blends
# 9                  hydrogen                    co2      co2 geological storage
# 10               monitoring         identification                hydrocarbons
# 11                petroleum            asphaltenes                      oxygen
# 12              leguminosae           phytoalexins            chemical looping
# 13                    water           geochemistry                 source rock
# 14    system identification       adaptive control              biodegradation
# 15          process control           optimization                   interface
# 16                      ccs                 brazil                   north sea
# 17                     coal                 carbon                      theory
# 18                 kinetics                kerogen           equation of state
# 19                 kinetics                   coal                     control
# 20                  kerogen                   coal            monoethanolamine
# 21                      co2                    ccs             bituminous coal
# 22                   theory      equation of state                 source rock
# 23                   diesel              emissions            power generation
# 24                 kinetics              pyrolysis               sequestration
# 25           carbon dioxide          sequestration                         esr
# 26           carbon dioxide                    ccs                         nmr
# 27            sequestration                    ccs                    planning
# 28          process control              modelling                     control
# 29          process control             simulation       mechanical properties
# ...                     ...                    ...                         ...
# 1024       power generation         postcombustion  carbon capture and storage
# 1025       power generation          precombustion                      theory
# 1026       power generation              oxyfiring           co2 sequestration
# 1027       power generation       chemical looping                 experiments
# 1028           oil refinery         oil extraction                      safety
# 1029           oil refinery         postcombustion       vitrinite reflectance
# 1030           oil refinery          precombustion                optimization
# 1031           oil refinery              oxyfiring                         oil
# 1032           oil refinery       chemical looping                         nmr
# 1033         oil extraction         postcombustion                     alkanes
# 1034         oil extraction          precombustion                         esr
# 1035         oil extraction              oxyfiring                   migration
# 1036         oil extraction       chemical looping       system identification
# 1037         postcombustion          precombustion                         co2
# 1038         postcombustion              oxyfiring                         esr
# 1039         postcombustion       chemical looping                       model
# 1040          precombustion              oxyfiring                      brazil
# 1041          precombustion       chemical looping            adaptive control
# 1042              oxyfiring       chemical looping              carbon capture
# 1043   parameter estimation  system identification                    kinetics
# 1044              transport              transport                      safety
# 1045             production              petroleum                   modelling
# 1046      equation of state                alkanes                       cubic
# 1047                 carbon                storage        numerical simulation
# 1048                 carbon               sleipner                     methane
# 1049                storage               sleipner                oil refinery
# 1050         biodegradation               toxicity                 co2 storage
# 1051   parameter estimation             simulation                      safety
# 1052             adsorption              interface                   structure
# 1053             morphology              structure                 natural gas
#
# [1054 rows x 3 columns]

# %% [markdown]
# ### Base de teste de Creator

# %% [markdown]
# A base de teste será composta por três colunas. As duas primeiras são de autores que publicaram em conjunto em um mesmo artigo, a terceira coluna conterá uma autor aleatório. Espera-se que o vetor do autor da primeira coluna esteja mais próximo do autor da segunda coluna do que da terceira. Para compor o corpus de teste de autores apenas serão considerados os 5 primeiros autores de cada artigo.

# %%
creator.head()
# Out:
#                                              Abstracts  \
# 0    [fur, polym, vol, pp, printed, great, britain,...
# 1    [fur, polym, vol, pp, printed, great, britain,...
# 10   [journal, organometallic, chemistry, elsevier,...
# 100  [geochimica, cosmochtmica, ada, vol, pp, copyr...
# 101  [emjca, physics, north, holland, publishing, c...
#
#                        Creator  \
# 0                gerrard, d.l.
# 1                  allan, j.r.
# 10       van leeuwen, p.w.n.m.
# 100  sundararaman, padmanabhan
# 101                emeis, c.a.
#
#                                                Doc2Vec
# 0    [-7.3716435432, 5.666041851, 10.190829277, -4....
# 1    [-6.6751461029, 4.3807458878, 6.8997917175, -6...
# 10   [-4.13864851, 15.6338815689, 19.3781089783, 2....
# 100  [-10.9760169983, -10.0097341537, -2.4555110931...
# 101  [-1.0575122833, 9.6217441559, 10.9673156738, -...

# %%
abstracts.head()
# Out:
#                                                Abstract Affiliate  \
# 0     [solid, catalysts, porous, solids, editorial, ...     Shell
# 1     [tetrahedron, letters, pp, pergamon, press, pr...     Shell
# 10    [analytica, chimica, ada, eisevier, scientific...     Shell
# 100   [journal, catalysis, mechanism, double, bond, ...     Shell
# 1000  [journal, organometallic, chemistry, elsevier,...     Shell
#
#                                                 Creator  \
# 0                       [zones, stacey, maxwell, ian e]
# 1                         [gray, r.t., reinhoudt, d.n.]
# 10                    [zeen, p.j., van grondelle, m.c.]
# 100                                     [brouwer, d.m.]
# 1000  [van leeuwen, p.w.n.m., kaftein, r., huis, r.,...
#
#                                 DOI       Date  \
# 0     10.1016/S1359-0286(97)80105-2 1997-02-28
# 1     10.1016/S0040-4039(00)75308-1 1975-12-31
# 10    10.1016/S0003-2670(01)93603-7 1980-08-01
# 100    10.1016/0021-9517(62)90005-2 1962-03-31
# 1000  10.1016/S0022-328X(00)91390-1 1976-01-20
#
#                                                 Doc2Vec Keywords  O&G  \
# 0     [-0.16553150120000001, -0.19028066100000002, 1...       []    1
# 1     [-8.4355430603, 8.8504123688, 18.3672981262, 2...       []    1
# 10    [-2.1989116669, -1.2150504589, 10.2875080109, ...       []    1
# 100   [-1.1215671301, 11.4992752075, 23.3098773956, ...       []    1
# 1000  [-7.6475477219, 17.9529323578, 13.5470266342, ...       []    1
#
#                                                   Title
# 0                    Solid catalysts and porous solids
# 1     Complexation of zeise's salt (KPtCl3·C2H4) by ...
# 10    An improved hydrogenation—microcoulometric met...
# 100   The mechanism of double-bond isomerization of ...
# 1000    Photolysis of methyl(triphenylphospine)gold(I)

# %%
max_creator = 5                             #Número máximo de autores que será considerado
n_article = len(abstracts)
creator_list = creator["Creator"].tolist() # Lista de Autores

# Criando um DataFrame para receber os pares de Autores que aparecem no mesmo artigo
# e o autor aleatório
test_corpus_creator = pd.DataFrame(columns=["Creator_1", "Creator_2", "Random_Creator"])

for article in abstracts.iterrows():  # Iterando sobre todos os artigos
    
    words = article[1]["Creator"]     # Célula do Dataframe onde se encontram os autores
    if words == []:                   # Se não houver keyword passa para próximo artigo
        pass
    
    else:
        for n in range(len(words)):   # Iterando sobre todos os autores de um artigo
            if n >= max_creator:      # Parar de iterar após o número máximo de autores
                break
            
            word_1 = words[n]         # Identificando primeiro autor
            
            # Como nem todos os autores estão na Lista de Autores é necessário 
            # verificar se word_1 está em creator_list 
            
            if word_1 in creator_list:
                for m in range(n+1, len(words)): # Iterando sobre os demais autores
                    if m >= max_creator:         # Parar de iterar após o número máximo de autores
                        break
                    
                    word_2 = words[m]            # Identificando segund0 autor
                    if word_2 in creator_list:
                        # Identificando autor aleatório
                        random_word = random.sample(creator_list, 1)[0]
                        # Adicionando os três autores no dataframe "test_corpus_creator"
                        test_corpus_creator.loc[len(test_corpus_creator)]= [word_1, word_2, random_word]

# %%
test_corpus_creator.to_csv("Test_Corpus_creator.csv")

# %%
test_corpus_creator
# Out:
#                   Creator_1              Creator_2          Random_Creator
# 0     van leeuwen, p.w.n.m.               huis, r.               zaera, f.
# 1     van leeuwen, p.w.n.m.          roobeek, c.f.   van leeuwen, p.w.n.m.
# 2                  huis, r.          roobeek, c.f.           halbert, t.r.
# 3                fray, g.i.           jaeger, r.h.           stork, w.h.j.
# 4                fray, g.i.       robinson, robert          rytter, erling
# 5              jaeger, r.h.       robinson, robert            parkes, d.a.
# 6            jacobson, a.j.          scanlon, j.c.          ghosh, amal k.
# 7            jacobson, a.j.     poeppelmeier, k.r.           bliault, alan
# 8            jacobson, a.j.            longo, j.m.          walker, a.i.t.
# 9             scanlon, j.c.     poeppelmeier, k.r.           stiefel, e.i.
# 10            scanlon, j.c.            longo, j.m.        de groot, c.p.m.
# 11       poeppelmeier, k.r.            longo, j.m.         pitkethly, r.c.
# 12                zaera, f.            gland, j.l.      hendriks, p.a.j.m.
# 13          reinhoudt, d.n.            de jong, f.           ziegler, p.a.
# 14               fray, g.i.       robinson, robert          longo, john m.
# 15                 de, s.k.               de, p.p.   moure, gustavo torres
# 16                 de, s.k.          peiffer, d.g.        lyon, richard k.
# 17                 de, p.p.          peiffer, d.g.           siegell, j.h.
# 18               vrieze, k.  van leeuwen, p.w.n.m.             helle, j.n.
# 19          chianelli, r.r.               wold, a.          moldowan, j.m.
# 20          chianelli, r.r.             dwight, k.        botto, robert i.
# 21                 wold, a.             dwight, k.           roberts, t.r.
# 22    van leeuwen, p.w.n.m.            praat, a.p.  schlosberg, richard h.
# 23             harper, t.r.             last, n.c.      johnston, david c.
# 24             taylor, r.i.           scales, l.e.          sherwood, r.d.
# 25         wachs, israel e.      kelemen, simon r.           jenkins, d.r.
# 26               yun, liang          bliault, alan          jacobson, a.j.
# 27              fraas, l.m.           mcleod, p.s.          pasqualini, r.
# 28              fraas, l.m.             cape, j.a.                smit, b.
# 29              fraas, l.m.          partain, l.d.              martin, b.
# ...                     ...                    ...                     ...
# 1688            allan, j.r.           carson, b.r.             zumofen, g.
# 1689            allan, j.r.          gerrard, d.l.       kelemen, simon r.
# 1690            allan, j.r.               hoey, s.              farago, b.
# 1691           carson, b.r.          gerrard, d.l.             grest, g.s.
# 1692           carson, b.r.               hoey, s.          petit, nicolas
# 1693          gerrard, d.l.               hoey, s.           peiffer, d.g.
# 1694           burton, j.j.       polizzotti, r.s.           maa, peter s.
# 1695     poeppelmeier, k.r.         jacobson, a.j.        chamberlin, r.v.
# 1696     poeppelmeier, k.r.            longo, j.m.    morken, anne kolstad
# 1697         jacobson, a.j.            longo, j.m.         zuiderweg, f.j.
# 1698            liang, k.s.           cramer, s.p.               zaera, f.
# 1699            liang, k.s.         johnston, d.c.            taylor, r.i.
# 1700            liang, k.s.         jacobson, a.j.             bennett, d.
# 1701           cramer, s.p.         johnston, d.c.           maddams, w.f.
# 1702           cramer, s.p.         jacobson, a.j.          clayfield, e.j
# 1703         johnston, d.c.         jacobson, a.j.          gouverneur, p.
# 1704            allan, j.r.           bowley, h.j.     de cazenove, thomas
# 1705            allan, j.r.          gerrard, d.l.            fetzer, j.c.
# 1706           bowley, h.j.          gerrard, d.l.           gerrard, d.l.
# 1707            ebert, l.b.          scanlon, j.c.        wachs, israel e.
# 1708          bennett, j.e.               mile, b.       gudmestad, ove t.
# 1709      silbernagel, b.g.      whittingham, m.s.        johnson, jack w.
# 1710            allan, j.r.            paton, a.d.              cossee, p.
# 1711            allan, j.r.             turvey, k.          pavlov, alexey
# 1712            allan, j.r.          gerrard, d.l.      hendriks, p.a.j.m.
# 1713            paton, a.d.             turvey, k.             burton, j.j
# 1714            paton, a.d.          gerrard, d.l.        iglesia, enrique
# 1715             turvey, k.          gerrard, d.l.              chen, j.g.
# 1716            richter, d.             farago, b.         chiquet, pierre
# 1717              prins, r.             biloen, p.            burton, j.j.
#
# [1718 rows x 3 columns]
