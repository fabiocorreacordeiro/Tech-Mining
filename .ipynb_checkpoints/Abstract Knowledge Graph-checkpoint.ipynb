# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd
import json
import gensim
import nltk
from  nltk.corpus import stopwords
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import common_texts, get_tmpfile
import datetime
import numpy as np
from sklearn.manifold import TSNE
from bokeh.models import ColumnDataSource, LabelSet, LayoutDOM, Plot
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
from bokeh.core.properties import Instance, String
from bokeh.resources import INLINE
import bokeh.io
from scipy.spatial import distance
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# Importando base concatenada e misturando os artigos para evitar que haja um viés devido a ordem de leitura dos documentos.

# %%
abstract = pd.read_json("Elsevier_abstract - Consolidado.json")
# Selecionando apenas os artigos de O&G
abstract_OG = abstract[abstract["O&G"] == 1]
# Misturando as linhas e resetando o index
abstract_OG = abstract_OG.sample(frac=1).reset_index(drop=True)

# %%
abstract_OG
# Out:
#                                                 Abstract          Affiliate  \
# 0                                                         BP United Kingdom
# 1                                                                   Statoil
# 2                                                                       Eni
# 3                                                          BP International
# 4                                                                   Statoil
# 5                                                                     Shell
# 6                                                                   Chevron
# 7                                                          BP International
# 8      55    Solid catalysts and porous solids  Edito...              Shell
# 9      Tetrahedron Letters No. 25, pp 2109 - 2112, 19...              Shell
# 10                                                                      Eni
# 11     JOURNAL OF COLLOID SCIENCE 13, 51-60 (1958)   ...              Shell
# 12     JOURNAL OF CATALYSIS 127, 332--341 (1991)    A...              Exxon
# 13                                                                Petrobras
# 14                                                                  Statoil
# 15                                                        BP United Kingdom
# 16                                                         BP International
# 17                                                                      Eni
# 18        Strategic   --  Information     Systems  EL...   BP International
# 19                                                         BP International
# 20     Solar energy and US  public utilities    The i...              Total
# 21     Giant Oil and Gas Fields of the Decade 1978-88...     BP Exploration
# 22     ECOTOXICOLOGY AND ENVIRONMENTAL SAFETY 7, 355-...              Shell
# 23     Structural constraints on the Tertiary plate t...  British Petroleum
# 24     ELSEVIER    Abstract    The Chemical Engineeri...              Shell
# 25                                                                   Repsol
# 26                                                                Petrobras
# 27                                                                      Eni
# 28     Analytica Chimica Ada, 118 (1980) 277 283    E...              Shell
# 29                                                                Petrobras
# ...                                                  ...                ...
# 15966                                                                 Exxon
# 15967                                                               Chevron
# 15968                                                               Statoil
# 15969  Physica 139 & 140B (1986) 746-749 North-Hollan...            Chevron
# 15970  Pergamon    0038-0717(95)00030-5    Soil Biol....              Shell
# 15971                                                               Chevron
# 15972                                                                 Total
# 15973  Geochimica et Cosmochimica Ada Vol. 54, pp, 23...              Shell
# 15974  Solar Cells, 1 (1979/80) 431 - 433            ...              Exxon
# 15975                                                                 Shell
# 15976  Thermochimica Ada, 115 (1987) 21-30           ...  British Petroleum
# 15977                                                                 Shell
# 15978                                                     British Petroleum
# 15979                                                             Petrobras
# 15980                                                                 Shell
# 15981  Fd Cosmet. Toxicol. Vol. 7, pp. 317-332. Perga...              Shell
# 15982  0 Acadbmie des sciences / Elsevier, Paris   Go...  BP United Kingdom
# 15983                                                                 Total
# 15984                                                                 Total
# 15985  Volume 19, number 3 PHYSICS LETTERS 15 October...              Shell
# 15986                                                                 Shell
# 15987                                                     BP United Kingdom
# 15988                                                                   Eni
# 15989                                                                 Shell
# 15990                                                                 Shell
# 15991                                                      BP International
# 15992  ELSEVIER    0016-2361(94)00251-0    Fuel Vol. ...  British Petroleum
# 15993  Oxidative weathering of Illinois No.6 coal    ...              Exxon
# 15994                                                      BP International
# 15995  Annals of Nuclear Energy, Vol. 3, pp. 41 to 53...              Exxon
#
#                                                  Creator  \
# 0      [Barker, R., Al Shaaili, I., De Motte, R.A., B...
# 1      [Friðleifsson, Guðmundur Ó., Elders, Wilfred A...
# 2      [Aste, N., Tagliabue, L.C., Del Pero, C., Test...
# 3      [Groison, Anne-Laure, Suquet, Marc, Cosson, Ja...
# 4                [SWAN, C., BASHIR, T., GUDMESTAD, O.T.]
# 5      [Acton, J., Ancliffe, C.B., Andres Canadell, J...
# 6      [Mali, Gwyn Ardeshir, Chapoy, Antonin, Tohidi,...
# 7      [Appiah Mensah, Alex, Akoto Sarfo, Daniel, Par...
# 8                        [Zones, Stacey, Maxwell, Ian E]
# 9                          [Gray, R.T., Reinhoudt, D.N.]
# 10     [van Sluisveld, Mariësse A.E., Harmsen, Mathij...
# 11                                         [Kahn, Allan]
# 12     [Ho, T.C., Jacobson, A.J., Chianelli, R.R., Lu...
# 13     [Monteiro, Carlos A.A., Costa, Denise, Zotin, ...
# 14                                           [Erdal, A.]
# 15     [Seddiki, Mohammed, Anouche, Karima, Bennadji,...
# 16     [Baton, Sophie D., Koenig, Michel, Guillou, Pe...
# 17     [Canavese, G., Scaltrito, L., Ferrero, S., Pir...
# 18                    [Andreu, Rafael, Ciborra, Claudio]
# 19     [Mozetič, M., Vesel, A., Primc, G., Eisenmenge...
# 20     [Dickson, Charles, Eichen, Marc, Feldman, Step...
# 21                                       [Roberts, D.G.]
# 22                                      [Smies, Maarten]
# 23                 [Hill, Kevin C., Hayward, Anthony B.]
# 24                                          [Wijn, E.F.]
# 25     [Jacquin, Mélanie, Jones, Deborah J., Rozière,...
# 26     [de Carvalho, Paulo Roberto Moura, Rasera, Lui...
# 27     [Costantini, Valeria, Gracceva, Francesco, Mar...
# 28                     [Zeen, P.J., Van Grondelle, M.C.]
# 29     [Tessarolo, Nathalia S., dos Santos, Luciana R...
# ...                                                  ...
# 15966  [Leitner, Christoph, Neubauer, Franz, Urai, Já...
# 15967    [Chaturvedi, T., Schembre, J.M., Kovscek, A.R.]
# 15968  [Nguyen, Tan, Miska, Stefan, Yu, Mengjiao, Tak...
# 15969                          [Bruno, M.S., Dunn, K.J.]
# 15970  [Young, C.S., Lethbridge, G., Shaw, L.J., Burn...
# 15971  [Durlofsky, Louis J., Jones, Richard C., Milli...
# 15972                                   [Ascher, Enrico]
# 15973                                  [Mango, Frank D.]
# 15974                       [Shaw, R.F., Ghosh, Amal K.]
# 15975  [Fratila-Apachitei, Lidy E., Kennedy, Maria D....
# 15976  [Allan, J.R., Pendlowski, M.J., Gerrard, D.L.,...
# 15977  [Erőss, Anita, Mádl-Szőnyi, Judit, Surbeck, He...
# 15978  [Liu, Xinliang, Bi, Xiaotao T., Liu, Chenguang...
# 15979  [de Sousa, F.V.V., da Mota, R.O., Quintela, J....
# 15980  [Janssen, Albert J.H., Lens, Piet N.L., Stams,...
# 15981  [Robinson, J., Roberts, M., Baldwin, M., Walke...
# 15982                   [Mahé, Gil, Olivry, Jean-Claude]
# 15983  [Aurshina, Afsha, Hingorani, Anil, Blumberg, S...
# 15984          [Moncorgé, A., Tchelepi, H.A., Jenny, P.]
# 15985         [Wilkens, J., De Graag, D.P., Helle, J.N.]
# 15986  [Appel, Matthias, Freeman, J.Justin, Gardner, ...
# 15987  [Glover, A.G., Gooday, A.J., Bailey, D.M., Bil...
# 15988  [Armetti, Giacomo, Migliazza, Maria Rita, Ferr...
# 15989  [Guedes Soares, C., Taylor, R. Eatock, Ewans, K.]
# 15990  [Hoekstra, Elly, Kersten, Sascha R.A., Tudos, ...
# 15991  [Vecchio, Riccardo, Decordi, Giulia, Grésillon...
# 15992  [Ladommatos, Nicos, Rubenstein, Paul, Bennett,...
# 15993       [Liotta, Ronald, Brons, Glen, Isaacs, James]
# 15994  [Hassenforder, Emeline, Ducrot, Raphaëlle, Fer...
# 15995                       [Dias, J.W.C., Merckx, K.R.]
#
#                                       DOI       Date  \
# 0            10.1016/j.apsusc.2018.10.238 2019-03-01
# 1        10.1016/j.jvolgeores.2018.08.013 2018-08-31
# 2            10.1016/j.renene.2014.11.026 2015-04-30
# 3       10.1016/j.aquaculture.2010.01.026 2010-03-23
# 4                  10.1006/jfls.2001.0425 2002-04-30
# 5      10.1016/B978-0-408-70719-0.50037-1 1976-12-31
# 6               10.1016/j.jct.2017.08.014 2018-02-28
# 7              10.1016/j.ejrs.2018.04.004 2018-12-18
# 8           10.1016/S1359-0286(97)80105-2 1997-02-28
# 9           10.1016/S0040-4039(00)75308-1 1975-12-31
# 10        10.1016/j.gloenvcha.2018.03.009 2018-05-31
# 11           10.1016/0095-8522(58)90008-4 1958-02-28
# 12           10.1016/0021-9517(92)90028-G 1992-11-30
# 13             10.1016/j.fuel.2015.07.054 2015-11-15
# 14          10.1016/S0955-5986(97)00032-0 1997-06-30
# 15          10.1016/j.enbuild.2016.08.023 2016-10-01
# 16             10.1016/j.hedp.2007.05.002 2007-10-31
# 17           10.1016/j.petrol.2015.01.008 2015-03-31
# 18          10.1016/S0963-8687(96)80039-4 1996-06-30
# 19              10.1016/j.tsf.2018.05.046 2018-08-30
# 20           10.1016/0301-4215(77)90036-2 1977-09-30
# 21           10.1016/0264-8172(94)90018-3 1994-02-28
# 22           10.1016/0147-6513(83)90001-5 1983-08-31
# 23           10.1016/0264-8172(88)90036-0 1988-02-29
# 24          10.1016/S0923-0467(96)03112-0 1996-09-30
# 25             10.1016/j.jcat.2004.09.017 2004-12-10
# 26          10.1016/j.jappgeo.2018.12.009 2019-02-28
# 27            10.1016/j.enpol.2005.11.002 2007-01-31
# 28          10.1016/S0003-2670(01)93603-7 1980-08-01
# 29           10.1016/j.chroma.2012.12.052 2013-03-01
# ...                                   ...        ...
# 15966           10.1016/j.jsg.2011.02.008 2011-05-31
# 15967          10.1016/j.coal.2008.08.002 2009-01-07
# 15968        10.1016/j.petrol.2011.04.018 2011-07-31
# 15969        10.1016/0378-4363(86)90691-1 1986-05-31
# 15970        10.1016/0038-0717(95)00030-I 1995-08-31
# 15971       10.1016/S0309-1708(96)00053-X 1997-12-31
# 15972           10.1016/j.jvs.2016.03.021 2016-06-30
# 15973        10.1016/0016-7037(90)90191-M 1990-01-31
# 15974        10.1016/0379-6787(80)90066-6 1980-08-31
# 15975       10.1016/S0376-7388(00)00557-3 2001-02-15
# 15976        10.1016/0040-6031(87)88347-8 1987-05-15
# 15977       10.1016/j.jhydrol.2012.01.031 2012-03-21
# 15978           10.1016/j.cej.2012.04.039 2012-06-15
# 15979     10.1016/j.electacta.2006.12.074 2007-10-10
# 15980     10.1016/j.scitotenv.2008.09.054 2009-02-01
# 15981       10.1016/S0015-6264(69)80368-8 1969-12-31
# 15982       10.1016/S1251-8050(99)80159-1 1999-05-15
# 15983          10.1016/j.jvsv.2017.04.010 2017-11-30
# 15984           10.1016/j.jcp.2017.02.032 2017-05-15
# 15985        10.1016/0031-9163(65)90052-1 1965-10-15
# 15986       10.1016/S0730-725X(01)00287-9 2001-05-31
# 15987  10.1016/B978-0-12-381015-1.00001-0 2010-12-31
# 15988          10.1016/j.tust.2018.02.012 2018-07-31
# 15989          10.1016/j.apor.2015.01.015 2015-06-30
# 15990          10.1016/j.jaap.2011.01.006 2011-05-31
# 15991           10.1016/j.wep.2017.04.001 2017-06-30
# 15992        10.1016/0016-2361(94)00251-7 1996-01-31
# 15993        10.1016/0016-2361(83)90028-5 1983-07-31
# 15994       10.1016/j.jenvman.2016.05.019 2016-09-15
# 15995        10.1016/0306-4549(76)90021-9 1976-12-31
#
#                                                 Keywords  O&G  \
# 0      [CO2 corrosion, Iron carbonate, Carbon steel, ...    1
# 1      [IDDP, Reykjanes, Supercritical fluids, Deep d...    1
# 2      [Luminescent solar concentrator, PV systems pe...    1
# 3      [Cryopreservation, \n                     Merl...    1
# 4                                                     []    1
# 5                                                     []    1
# 6               [Gas hydrates, Kinetics, Induction time]    1
# 7      [Land use/cover change, Change detection, Supe...    1
# 8                                                     []    1
# 9                                                     []    1
# 10     [Technology diffusion, Integrated assessment, ...    1
# 11                                                    []    1
# 12                                                    []    1
# 13     [Hydroconversion, Ring opening, Decalin, Diese...    1
# 14     [computational fluid dynamics, flow conditione...    1
# 15     [Thermal renovation, Masonry buildings, PROMET...    1
# 16     [Laser–plasma interaction, Fast electron trans...    1
# 17     [Oil pipeline, Pigging, Utility pigs, Pipeline...    1
# 18     [Capability development, Resource-based view, ...    1
# 19                                                    []    1
# 20                                                    []    1
# 21                                                    []    1
# 22                                                    []    1
# 23     [Structural constraints, plate tectonics, Tert...    1
# 24     [Downcomer layout pattern, Tray efficiency, Di...    1
# 25     [Supported bimetallic catalyst, Hydrogenation/...    1
# 26     [Information decomposition, Artifact removal, ...    1
# 27     [Energy security, Energy scenarios, Energy mar...    1
# 28                                                    []    1
# 29             [GC×GC-TOFMS, Bio-oil composition, GC–MS]    1
# ...                                                  ...  ...
# 15966  [Haselgebirge, Rocksalt, Halite, Hydrofracturi...    1
# 15967  [Wettability, CO2 sequestration, Coal-bed meth...    1
# 15968  [dynamic barite sag, sag shoe, eccentricity, d...    1
# 15969                                                 []    1
# 15970                                                 []    1
# 15971                                                 []    1
# 15972                                                 []    1
# 15973                                                 []    1
# 15974                                                 []    1
# 15975  [Ultrafiltration, Morphology, Pores, Flux, Blo...    1
# 15976                                                 []    1
# 15977  [Radioactive isotopes, Karst aquifer, Regional...    1
# 15978  [Microwave heating, Pine bark, Demineralizatio...    1
# 15979  [Polyurethane foam, Impedance, Thermal insulat...    1
# 15980  [Biological sulfur cycle, Sulfate reduction, S...    1
# 15981                                                 []    1
# 15982  [West Africa, Central Africa, freshwater, Atla...    1
# 15983                                                 []    1
# 15984  [Nonlinear dynamics, Numerical flow simulation...    1
# 15985                                                 []    1
# 15986  [NMR relaxation, Porous media, Internal field ...    1
# 15987                                                 []    1
# 15988  [Open gripper main beam TBM, TBM performance p...    1
# 15989                                                 []    1
# 15990  [Biomass, Fast pyrolysis, Bio oil, Upgraded py...    1
# 15991  [Wine, Health, Moderate consumption, France, I...    1
# 15992  [hydrocarbons, sooting tendency, molecular str...    1
# 15993  [bituminous coal, oxidativa weathering, coal s...    1
# 15994  [Mixed-methods, Triangulation, Theory-based ev...    1
# 15995                                                 []    1
#
#                                                    Title
# 0      Iron carbonate formation kinetics onto corrodi...
# 1      The Iceland Deep Drilling Project at Reykjanes...
# 2      Performance analysis of a large-area luminesce...
# 3      Sperm motility in European hake, Merluccius me...
# 4      NONLINEAR INERTIAL LOADING. PART I: ACCELERATI...
# 5                                   LIST OF PARTICIPANTS
# 6      Investigation into the effect of subcooling on...
# 7      Assessment of vegetation dynamics using remote...
# 8                     Solid catalysts and porous solids
# 9      Complexation of zeise's salt (KPtCl3·C2H4) by ...
# 10     Comparing future patterns of energy system cha...
# 11     The flocculation of sodium montmorillonite by ...
# 12     Hydrodenitrogenation-selective catalysts I. Fe...
# 13     Effect of metal–acid site balance on hydroconv...
# 14     A numerical investigation of different paramet...
# 15     A multi-criteria group decision-making method ...
# 16     Relativistic electron transport and confinemen...
# 17     A novel smart caliper foam pig for low-cost pi...
# 18     Organisational learning and core capabilities ...
# 19     Recent developments in surface science and eng...
# 20     Solar energy and US public utilities The impac...
# 21     Giant oil and gas fields of the decade 1978–88...
# 22     On the relevance of microecosystems for risk a...
# 23     Structural constraints on the Tertiary plate t...
# 24     The effect of downcomer layout pattern on tray...
# 25     Cetane improvement of diesel with a novel bime...
# 26     Variogram modeling of broadband artifacts of a...
# 27     Security of energy supply: Comparing scenarios...
# 28     An improved hydrogenation—microcoulometric met...
# 29     Chemical characterization of bio-oils using co...
# ...                                                  ...
# 15966  Structure and evolution of a rocksalt-mudrock-...
# 15967  Spontaneous imbibition and wettability charact...
# 15968  Experimental study of dynamic barite sag in oi...
# 15969  Does the Hertz solution estimate pressures cor...
# 15970  Survival of inoculated Bacillus cereus spores ...
# 15971  A nonuniform coarsening approach for the scale...
# 15972  VS01. Adjunctive Arteriovenous Fistula and Vei...
# 15973     The origin of light cycloalkanes in petroleum
# 15974              Selenium heterostructure solar cells
# 15975  Influence of membrane morphology on the flux d...
# 15976  The thermal, spectral and magnetic studies of ...
# 15977  Radionuclides as natural tracers for the chara...
# 15978  Performance of Fe/AC catalyst prepared from de...
# 15979  Characterization of corrosive agents in polyur...
# 15980  Application of bacteria involved in the biolog...
# 15981  The pharmacokinetics of HEOD (dieldrin) in the...
# 15982  Assessment of freshwater yields to the ocean a...
# 15983  Shortened protocol for radiofrequency ablation...
# 15984  Modified sequential fully implicit scheme for ...
# 15985  Electron spin resonance of neutral rhodium in ...
# 15986  Interpretation of restricted diffusion in sand...
# 15987  Chapter One Temporal Change in Deep-Sea Benthi...
# 15988  Geological and mechanical rock mass conditions...
# 15989       Safe offloading from floating LNG platforms
# 15990  Possibilities and pitfalls in analyzing (upgra...
# 15991  European consumers’ perception of moderate win...
# 15992  Some effects of molecular structure of single ...
# 15993        Oxidative weathering of Illinois No.6 coal
# 15994  Four challenges in selecting and implementing ...
# 15995                 Theories of fission gas behaviour
#
# [15996 rows x 8 columns]

# %% [markdown]
# ## Pré-processamento

# %% [markdown]
# Retirando palavras e espaços

# %%
# Retirando as palavras "Abstract", "Unknown", "Publisher Summary", "Summary", "Fundamento"
# que aparece no início de vários textos
abstract_OG["Abstract"] = abstract_OG["Abstract"].str.replace("Abstract", "")
abstract_OG["Abstract"] = abstract_OG["Abstract"].str.replace("Unknown", "")
abstract_OG["Abstract"] = abstract_OG["Abstract"].str.replace("Publisher Summary", "")
abstract_OG["Abstract"] = abstract_OG["Abstract"].str.replace("Summary", "")
abstract_OG["Abstract"] = abstract_OG["Abstract"].str.replace("Fundamento", "")

# %%
# Separando o texto em uma lista de palavras desconsiderando espaços e \n
abstract_OG["Abstract"] = abstract_OG["Abstract"].str.split()      
# Unificando a lista de palavras usando espaços simples
abstract_OG["Abstract"] = abstract_OG["Abstract"].str.join(" ")

# %% [markdown]
# Eliminar as linhas sem Abstract

# %%
abstract_OG = abstract_OG[abstract_OG["Abstract"] != ""]
abstract_OG = abstract_OG.reset_index()
abstract_OG = abstract_OG.drop(columns=['index'])

# %% [markdown]
# Realizando o pré-processamento simple do Gensim basicamente para gerar os tokens dos textos

# %%
abstract_OG["Abstract"] = abstract_OG["Abstract"].apply(gensim.utils.simple_preprocess)

# %%
# Importando as bibliotecas de stopwords
#nltk.download('stopwords')
# Mapeando stopwords com NLTK
stopwordsIngles = stopwords.words("english")

def remove_stopwords(abstract):
    without_stopwords = []
    for word in abstract:
        if word not in stopwordsIngles:
            without_stopwords.append(word)
    return(without_stopwords)
    
# Excluindo stopwords
abstract_OG["Abstract"] = abstract_OG["Abstract"].apply(remove_stopwords)

# %% [markdown]
# Fazer pré-processamento das keywords e Creators

# %%
#Procurar "keyword" e "creator" em todos os artigos de O&G

momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

n = 0

for index, row in abstract_OG.iterrows():
    n = n+1
    preprocess_key = []
    preprocess_creator = []
   
    row_keywords = row["Keywords"]  # Selecionar keywords
    for word in row_keywords:       # Looping em cada keyword
        word = word.strip()         # Retirando espaços em branco
        word = word.lower()         # Todas letras em minúsculo
        preprocess_key.append(word)
        
    row_creators = row["Creator"]   # Selecionar autores
    for word in row_creators:       # Looping em cada keyword
        word = word.strip()         # Retirando espaços em branco
        word = word.lower()         # Todas letras em minúsculo
        preprocess_creator.append(word)
        
    abstract_OG["Keywords"][index] = preprocess_key
    abstract_OG["Creator"][index] = preprocess_creator

    if n%1000 == 0:
        print ("Artigos pré-processados: ", n)
        
momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Artigos pré-processados:  1000
# Artigos pré-processados:  2000
# Artigos pré-processados:  3000
# Artigos pré-processados:  4000
# Artigos pré-processados:  5000
# Artigos pré-processados:  6000
# Tempo total decorrido:  0:51:53.410324

# %% [markdown]
# Gravando arquivo Pré-processado

# %%
abstract_OG.to_json("Elsevier_abstract - Preprocessado.json", date_format = 'iso')
abstract_OG = pd.read_json("Elsevier_abstract - Preprocessado.json")

# %% [markdown]
# ## Vetorizando os documentos

# %% [markdown]
# Gerando os modelos Doc2Vec utilizando os artigos provenientes do conjunto de treino

# %%
momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

# Todos os documentos devem passar pela função TaggedDocument antes de ser vetorizado
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(abstract_OG["Abstract"])]

#Hiperparâmetros do modelo Doc2Vec
Abstract_doc2vec = Doc2Vec(documents,
                           vector_size=8,
                           dm=1,
                           window=5,
                           min_count=250,
                           workers=7,
                           epochs=300,
                           alpha=0.025,
                           min_alpha=0.00025)

momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)
# Out:
# Tempo total decorrido:  0:30:35.981490

# %%
# Gravando modelo Doc2Vec
fname = "AbstractKG_doc2vec_model"
Abstract_doc2vec.save(fname)

# %%
# Lendo modelo Doc2Vec
fname = "AbstractKG_doc2vec_model"
Abstract_doc2vec = Doc2Vec.load(fname)

# %%
# Utilizar o modelo Doc2Vec gerado para inferir os vetores para todos os artigos.

momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

abstract_OG["Doc2Vec"] = abstract_OG["Abstract"].apply(Abstract_doc2vec.infer_vector)

momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)
# Out:
# Tempo total decorrido:  1:21:27.422130

# %% [markdown]
# Gravando arquivo com Doc2Vec inferido

# %%
abstract_OG.to_json("Elsevier_abstract - Preprocessado.json", date_format = 'iso')
abstract_OG = pd.read_json("Elsevier_abstract - Preprocessado.json")

# %%
# Retornando um exemplo com os 6 documentos mais similares (o próprio + top5)
top5 = Abstract_doc2vec.docvecs.most_similar([Abstract_doc2vec.docvecs[0]], topn=6)
for n in top5:
    print("Abstract ", n, "----> ", abstract_OG.loc[n[0]]["Title"])
# Out:
# Abstract  (0, 1.0) ---->  Solid catalysts and porous solids
# Abstract  (2326, 0.9905878901481628) ---->  Hydroprocessing kinetics for oil fractions
# Abstract  (578, 0.9891272783279419) ---->  Les liaisons dangereuses Editorial overview
# Abstract  (1079, 0.9476644992828369) ---->  Factors controlling the mode by which a catalyst operates in the graphite-oxygen reaction
# Abstract  (6767, 0.9461300373077393) ---->  Containment Impact of Calcite Pathways in the Primary Caprock of CO2 Storage in a Depleted North Sea Gas Field
# Abstract  (701, 0.9460945725440979) ---->  Decentralized energy supply Suitability for the UK's industrial sectors
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# ## Vetorizando as keywords

# %% [markdown]
# Nesta seção serão gerados vetores para as principais keywords que aparecem nos artigos de O&G. Para tal, será gerado uma lista de keywords. Para cada keyword dessa lista serão identificados e concatenados os abstracts a qual essa keyword está relacionada. O vetor da keyword será o vetor Doc2Vec inferido para o texto dos abstracts concatenados utilizado o modelo já treinado.

# %%
# Identificando as keywords de O&G que parecem mais de 5 vezes

# frequência mínima para uma keyword ser considerada
min_freq = 6 
# Separando os artigos de O&G
keyword_list = abstract_OG
keywords = []

# Incluindo keywords de cada artigo na lista "keywords"
keyword_list["Keywords"].apply(keywords.extend)               

# Criando DataFrame com a frequência das keywords
keywords = pd.Series(keywords)
keywords = pd.DataFrame(data={"Frequency": keywords.value_counts()})
# Retirand as keywords com Frequência menor do que min_freq
keywords = keywords[keywords["Frequency"] >= min_freq]

# %%
# Concatenando todos os abstracts de uma mesma keyword

momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

# Criando DataFrame para armazenar os Abstracts concatenados das keywords
keyword_vectors = pd.DataFrame(columns=['Keywords', 'Abstracts'])

# Fazer uma iteração para todas as keywords
for key in keywords.index:
    abstracts = []
      
    #Procurar a keyword em todos os artigos de O&G
    for index, row in abstract_OG.iterrows():

       # Verificar se a Keyword procurada está nesse artigo
        if key in row["Keywords"]:
            # Concatenar abstracts
            abstracts.extend(row["Abstract"])
     
    # Incluir linha no DataFrame "keyword_vectors"
    keyword_vectors = keyword_vectors.append({'Keywords': key, 'Abstracts': abstracts}, ignore_index=True)
    
momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)
# Out:
# Tempo total decorrido:  0:00:50.924619

# %%
# Para não precisar repetir as etapas anteriores (separar keywords e concatenar os textos) lemos diretamento do disco
#keyword_vectors = pd.read_json("Elsevier_abstract - Keywords.json")

# %%
# Utilizando o modelo já treinado inferir os vetores para as keywords
momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

keyword_vectors["Doc2Vec"] = keyword_vectors["Abstracts"].apply(Abstract_doc2vec.infer_vector)

momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)

# %%
# Salvando e lendo em disco a lista de keyword com abstracts
keyword_vectors.to_json("Elsevier_abstract - Keywords.json", date_format = 'iso')
keyword_vectors = pd.read_json("Elsevier_abstract - Keywords.json")

# %%
keyword_vectors.head()

# %% [markdown]
# É necessário reduzir a dimensionalidade dos vetores de 50 para 2 para conseguir gerar uma visualização. Será utilizado o algoritmo tSNE.

# %%
# Reduzindo de 50 dimensões para 2 usando tSNE para permitir a plotagem
tsne = TSNE(n_components=2, random_state=0, perplexity=12,early_exaggeration=10  )
embed_tsne = tsne.fit_transform(keyword_vectors["Doc2Vec"].tolist())
embed_tsne = pd.DataFrame(data=embed_tsne)

# %%
#Definindo uma função que recebe os vetores já reduzidos para duas dimensões e plota o gráfico
def scater_plot(embed_tsne, vocabulario, color):
    p = figure(tools="pan,wheel_zoom,reset",#save",
               toolbar_location="above",
               title=" ",
               plot_width=800, 
               plot_height=500)

    source = ColumnDataSource(data=dict(x1=embed_tsne[0],
                                        x2=embed_tsne[1],
                                        names=vocabulario))

    p.scatter(x="x1", y="x2", size=8, source=source, color=color)

    labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                      text_font_size="8pt", text_color="#555555",
                      source=source, text_align='center')
    p.add_layout(labels)
    bokeh.io.output_notebook(INLINE) 
    output_notebook()
    show(p)
    return()

# Plotando o grafico
scater_plot(embed_tsne, keyword_vectors["Keywords"], 'CornflowerBlue')

# %% [markdown]
# ## Vetorizando os autores

# %% [markdown]
# A mesma técnica utilizada para se criar os vetores das Keywords será utilizada para se vetorizar os autores dos documentos.

# %%
# Identificando autores de O&G que parecem mais de 5 vezes

# frequência mínima para um autor ser considerada
min_freq = 6
# Separando os artigos de O&G
creator_list = abstract_OG
creators = []
# Incluindo autor de cada artigo na lista "creators"
creator_list["Creator"].apply(creators.extend)               

# Criando DataFrame com a frequência dos autores
creators = pd.Series(creators)
creators = pd.DataFrame(data={"Frequency": creators.value_counts()})
# Retirand as keywords com Frequência menor do que min_freq
creators = creators[creators["Frequency"] >= min_freq]

# %%
# Concatenando todos os abstracts de um mesmo autor

momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

# Criando DataFrame para armazenar os Abstracts concatenados dos autores
creator_vectors = pd.DataFrame(columns=['Creator', 'Abstracts'])

# Fazer uma iteração para todos os autores
for key in creators.index:
    
    abstracts = []
   
    #Procurar os autores em todos os artigos de O&G
    for index, row in abstract_OG.iterrows():

        # Verificar se o autor procurado está nesse artigo
        if key in row["Creator"]:
            # Concatenar abstracts
            abstracts.extend(row["Abstract"])
     
    # Incluir linha no DataFrame "creator_vectors"
    creator_vectors = creator_vectors.append({'Creator': key, 'Abstracts': abstracts}, ignore_index=True)
    
momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)

# %%
# Para não precisar repetir as etapas anteriores (separar autores e concatenar os textos) lemos diretamento do disco
#creator_vectors = pd.read_json("Elsevier_abstract - Creators.json")

# %%
# Utilizando o modelo já treinado inferir os vetores para os autores
momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

creator_vectors["Doc2Vec"] = creator_vectors["Abstracts"].apply(Abstract_doc2vec.infer_vector)

momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)

# %%
# Salvando e lendo em disco a lista de autores com abstracts
creator_vectors.to_json("Elsevier_abstract - Creators.json", date_format = 'iso')
creator_vectors = pd.read_json("Elsevier_abstract - Creators.json")

# %%
creator_vectors.head()

# %% [markdown]
# É necessário reduzir a dimensionalidade dos vetores de 100 para 2 para conseguir gerar uma visualização. Será utilizado o algoritmo tSNE.

# %%
# Reduzindo de 100 dimensões para 2 usando tSNE para permitir a plotagem
tsne = TSNE(n_components=2, random_state=0, perplexity=12,early_exaggeration=10  )
embed_tsne = tsne.fit_transform(creator_vectors["Doc2Vec"].tolist())
embed_tsne = pd.DataFrame(data=embed_tsne)

# %%
# Plotando o grafico
scater_plot(embed_tsne, creator_vectors["Creator"], 'CornflowerBlue')

# %% [markdown]
# ### Unindo os diversos vetores

# %% [markdown]
# Nesta seção será criado um dataframe com os três tipos de vetores: artigo, keyword e autor. Dessa forma, essas três entidades poderão ser analisadas no mesmo espaço vetorial

# %%
#Criando o dataframe multi_vector que irá receber os três tipos de vetores
multi_vector = pd.DataFrame(columns=['Type_vec', 'Description', 'Doc2Vec'])

# %%
#Adicionando os vetores dos artigos no multi_vector
multi_vector_article = pd.DataFrame(columns=['Type_vec', 'Description', 'Doc2Vec', 'Date', 'Affiliate'])
multi_vector_article [['Description', 
                       'Doc2Vec', 
                       'Date', 
                       'Affiliate']] = abstract_OG[['Title', 
                                                    'Doc2Vec', 
                                                    'Date', 
                                                    'Affiliate']]
#multi_vector_article ['Doc2Vec']= abstract_OG['Doc2Vec']
multi_vector_article['Type_vec'] = 'Article'
multi_vector_article = multi_vector_article#.head(1000)
multi_vector = pd.concat([multi_vector, multi_vector_article], ignore_index=True)

# %%
#Adicionando os vetores das keywords no multi_vector
multi_vector_keyword = pd.DataFrame(columns=['Type_vec', 'Description', 'Doc2Vec'])
multi_vector_keyword [['Description', 'Doc2Vec']]= keyword_vectors[['Keywords', 'Doc2Vec']]
multi_vector_keyword['Type_vec'] = 'Keywords'
multi_vector = pd.concat([multi_vector, multi_vector_keyword], ignore_index=True)

# %%
#Adicionando os vetores dos autores no multi_vector
multi_vector_creator = pd.DataFrame(columns=['Type_vec', 'Description', 'Doc2Vec'])
multi_vector_creator [['Description', 'Doc2Vec']]= creator_vectors[['Creator', 'Doc2Vec']]
multi_vector_creator['Type_vec'] = 'Creator'
multi_vector = pd.concat([multi_vector, multi_vector_creator], ignore_index=True)

# %%
# Reduzindo de 100 dimensões para 2 usando tSNE para permitir a plotagem
momentoInicial = datetime.datetime.now()   # Inicia um contador do tempo

tsne = TSNE(n_components=2, random_state=0, perplexity=12,early_exaggeration=10  )
embed_tsne = tsne.fit_transform(multi_vector["Doc2Vec"].tolist())
embed_tsne = pd.DataFrame(data=embed_tsne)

momentoFinal = datetime.datetime.now() #Encerrando o contador do tempo
print("Tempo total decorrido: ", momentoFinal - momentoInicial)

# %%
# Acrescentando as duas dimensões do tSNE no dataframe
multi_vector["TSNE_1"] = embed_tsne[0]
multi_vector["TSNE_2"] = embed_tsne[1]

# %%
#Gravando o dataframe
multi_vector.to_csv("Elsevier_abstract - Multivector.csv")

# %%
# Realizando uma consulta de acordo com a coluna "Description" 
# e retornando os N vetores mais próximos
query = "oil"   #Termo consultado
n_answer = 20     #Número de respostas

# Indentificando o vetor da query
query_vector = multi_vector[multi_vector["Description"] == query]["Doc2Vec"].values[0]

#Criando um Dataframe para a query
multi_vector_query = multi_vector 

#Acrescentando uma coluna com as distâncias e selecionando o N mais próximos
multi_vector_query["DisQuery"] = (multi_vector["Doc2Vec"].
                                  apply(lambda x: distance.
                                        cosine(x , query_vector)))
multi_vector_query = (multi_vector_query.nsmallest(n_answer, "DisQuery")
                      .sort_values("DisQuery"))
multi_vector_query

# %%
# Plotando o grafico
scater_plot([multi_vector_query["TSNE_1"],multi_vector_query["TSNE_2"]], 
            multi_vector_query["Description"], 
            'CornflowerBlue')
