# %% [markdown]
# Importando bliotecas

# %%
import pandas as pd
import random

# %% [markdown]
# Lendo arquivos

# %%
keywords = pd.read_json("Elsevier_abstract_complete_text - Keywords.json")
creator = pd.read_json("Elsevier_abstract_complete_text - Creators.json")
abstracts = pd.read_json("Elsevier_abstract_complete_text - Preprocessado.json")

# %% [markdown]
# ### Base de teste de Keywords

# %% [markdown]
# A base de teste será composta por três colunas. As duas primeiras são de keywords que ocorrem em conjunto em um mesmo artigo, a terceira coluna conterá uma keyword aleatória. Espera-se que o vetor da keyword da primeira coluna esteja mais próximo da keyword da segunda coluna do que da terceira.

# %%
n_article = len(abstracts)
keywords_list = keywords["Keywords"].tolist() # Lista de Keywords

# Criando um DataFrame para receber os pares de keywords que aparecem no mesmo artigo
# e a keyword aleatória
test_corpus_keyword = pd.DataFrame(columns=["Keyword_1", "Keyword_2", "Random_keyword"])

for article in abstracts.iterrows():  # Iterando sobre todos os artigos
   
    words = article[1]["Keywords"]    # Célula do Dataframe onde se encontram as keywords
    if words == []:                   # Se não houver keyword passa para próximo artigo
        pass
    
    else:
        for n in range(len(words)):   # Iterando sobre todos as keywords de um artigo
            word_1 = words[n]         # Identificando primeira keyword
            # Como nem todas as keywords estão na Lista de Keywords é necessário 
            # verificar se word_1 está em keyword_list 
            if word_1 in keywords_list:
                
                for m in range(n+1, len(words)): # Iterando sobre as demais keywords
                    word_2 = words[m] # Identificando segunda keyword
                    if word_2 in keywords_list:
                        # Identificando keyword aleatória
                        random_word = random.sample(keywords_list, 1)[0]
                        # Adicionando as três keywords no dataframe "test_corpus"
                        test_corpus_keyword.loc[len(test_corpus_keyword)]= [word_1, word_2, random_word]

# %%
test_corpus_keyword.to_csv("Test_Corpus_keywords.csv")

# %%
test_corpus_keyword
# Out:
#                       Keyword_1                  Keyword_2  \
# 0                       neogene               paleoecology
# 1         eastern mediterranean                speleothems
# 2         eastern mediterranean               paleoclimate
# 3                   speleothems               paleoclimate
# 4          são francisco craton                u–pb dating
# 5                        drying              hydrodynamics
# 6             deformation bands                   faulting
# 7             deformation bands                 cataclasis
# 8             deformation bands               permeability
# 9                      faulting                 cataclasis
# 10                     faulting               permeability
# 11                   cataclasis               permeability
# 12               carbon dioxide                        co2
# 13                     sediment                     france
# 14                     sediment                     france
# 15                       france                     france
# 16                 biogeography                   taxonomy
# 17                mediterranean             geoarchaeology
# 18                mediterranean                   holocene
# 19               geoarchaeology                   holocene
# 20                  wettability        interfacial tension
# 21                  wettability       numerical simulation
# 22          interfacial tension       numerical simulation
# 23               stable isotope              trace element
# 24                         mars              sedimentology
# 25                         mars               stratigraphy
# 26                         mars                 alteration
# 27                sedimentology               stratigraphy
# 28                sedimentology                 alteration
# 29                 stratigraphy                 alteration
# ...                         ...                        ...
# 74583           biostratigraphy                   dévonien
# 74584           biostratigraphy                     brésil
# 74585                  devonian                     brazil
# 74586                  devonian                  miospores
# 74587                  devonian           biostratigraphie
# 74588                  devonian                   dévonien
# 74589                  devonian                     brésil
# 74590                    brazil                  miospores
# 74591                    brazil           biostratigraphie
# 74592                    brazil                   dévonien
# 74593                    brazil                     brésil
# 74594                 miospores           biostratigraphie
# 74595                 miospores                   dévonien
# 74596                 miospores                     brésil
# 74597          biostratigraphie                   dévonien
# 74598          biostratigraphie                     brésil
# 74599                  dévonien                     brésil
# 74600       rare earth elements           paleoceanography
# 74601       rare earth elements          paleoenvironments
# 74602       rare earth elements               campos basin
# 74603          paleoceanography          paleoenvironments
# 74604          paleoceanography               campos basin
# 74605         paleoenvironments               campos basin
# 74606      dinoflagellate cysts   calcareous nannoplankton
# 74607      dinoflagellate cysts                alboran sea
# 74608      dinoflagellate cysts  messinian salinity crisis
# 74609  calcareous nannoplankton                alboran sea
# 74610  calcareous nannoplankton  messinian salinity crisis
# 74611               alboran sea  messinian salinity crisis
# 74612              biogeography                temperature
#
#                      Random_keyword
# 0                           climate
# 1                      optimisation
# 2                        geophysics
# 3                            taiwan
# 4                sediment transport
# 5               cosmogenic nuclides
# 6              organic geochemistry
# 7                        subduction
# 8                           gravity
# 9                     trace element
# 10                  detrital zircon
# 11                            tchad
# 12                 contourite drift
# 13                           europe
# 14                       depression
# 15                         pockmark
# 16              chemical weathering
# 17               structural geology
# 18                   dolomitization
# 19                        lower fan
# 20                  land use change
# 21                         micro-ct
# 22                         po plain
# 23                 paleoenvironment
# 24                              oil
# 25          hydrothermal alteration
# 26                  seismotectonics
# 27                sea-level changes
# 28             geological processes
# 29                       antarctica
# ...                             ...
# 74583          reservoir simulation
# 74584                    efficiency
# 74585                   cosmic rays
# 74586                   east africa
# 74587                       ecology
# 74588                    palaeozoic
# 74589          fold and thrust belt
# 74590  principal component analysis
# 74591                      himalaya
# 74592                    3d seismic
# 74593                  conservation
# 74594        monte carlo simulation
# 74595                   radiocarbon
# 74596                         maroc
# 74597                 late holocene
# 74598              active tectonics
# 74599                        tethys
# 74600                  paraná basin
# 74601         french massif central
# 74602                identification
# 74603            equations of state
# 74604            sediment transport
# 74605                        jordan
# 74606                        drying
# 74607                     inversion
# 74608                  bioturbation
# 74609                       imaging
# 74610                       seepage
# 74611                  reactivation
# 74612                       archean
#
# [74613 rows x 3 columns]

# %% [markdown]
# ### Base de teste de Creator

# %% [markdown]
# A base de teste será composta por três colunas. As duas primeiras são de autores que publicaram em conjunto em um mesmo artigo, a terceira coluna conterá uma autor aleatório. Espera-se que o vetor do autor da primeira coluna esteja mais próximo do autor da segunda coluna do que da terceira. Para compor o corpus de teste de autores apenas serão considerados os 5 primeiros autores de cada artigo.

# %%
creator.head()
# Out:
#                                                Abstract  \
# 0     [detailed, experimental, data, including, temp...
# 1     [presently, upwelling, is, of, major, importan...
# 10    [mineralogical, geochemical, structural, and, ...
# 100   [bench, top, nuclear, magnetic, resonance, nmr...
# 1000  [combined, pb, and, lu, hf, isotope, data, fro...
#
#                         Creator  \
# 0     kontogeorgis, georgios m.
# 1     sinninghe damsté, jaap s.
# 10          cathelineau, michel
# 100                may, eric f.
# 1000             laurent, oscar
#
#                                                 Doc2Vec
# 0     [-0.3611550033, -0.43343284730000003, -6.01175...
# 1     [2.1407284737, -1.3675658703, 1.5672086477, -1...
# 10    [-0.4575897157, -0.6269447207000001, 0.9252625...
# 100   [0.43091979620000004, -0.6002904773000001, -4....
# 1000  [1.3626121283, -1.6888669729, 4.8119444847, 0....

# %%
abstracts.head()
# Out:
#                                                Abstract Affiliate  \
# 0     [the, llate, miocene, chagres, formation, from...      None
# 1     [coal, exploration, and, mining, in, extensive...      None
# 10    [the, climate, of, the, eastern, mediterranean...      None
# 100   [extensive, carbonate, siliciclastic, successi...      None
# 1000  [experimental, data, and, theoretical, conside...      None
#
#                                                 Creator  \
# 0     [carrillo-briceño, jorge d., de gracia, carlos...
# 1      [falivene, oriol, cabrera, lluís, sáez, alberto]
# 10    [bar-matthews, miryam, ayalon, avner, kaufman,...
# 100   [paula-santos, gustavo macedo, babinski, marly...
# 1000            [akulich, p., reyes, a., bubnovich, v.]
#
#                                 DOI       Date  \
# 0      10.1016/j.jsames.2015.02.001 2015-07-31
# 1        10.1016/j.coal.2006.08.008 2007-07-02
# 10    10.1016/S0012-821X(98)00275-1 1999-02-28
# 100        10.1016/j.gr.2014.07.012 2015-09-30
# 1000   10.1016/j.powtec.2006.06.009 2006-09-26
#
#                                                 Doc2Vec  \
# 0     [-0.9903196096, -0.5715711713, 0.9309846759, -...
# 1     [-2.1212005615, -0.1022151932, -0.0258647818, ...
# 10    [0.5599007607, -0.7720896602, 0.6178017855, 3....
# 100   [-1.8700487614, -0.0986065343, -0.9389336109, ...
# 1000  [2.4532382488, -1.3665482998, -0.0808711872, 1...
#
#                                                Keywords Raw_text  \
# 0     [neogene, tropical america, panama canal basin...
# 1     [3d facies interpolation, indicator kriging, a...
# 10    [eastern mediterranean, speleothems, paleoclim...
# 100   [bambuí group, são francisco craton, u–pb dati...
# 1000  [spouting bed, drying, hydrodynamics, peripher...
#
#                                                   Title
# 0     A new Late Miocene chondrichthyan assemblage f...
# 1     Optimum and robust 3D facies interpolation str...
# 10    The Eastern Mediterranean paleoclimate as a re...
# 100   New evidence of an Ediacaran age for the Bambu...
# 1000  Effect of peripheral gas jets on hydrodynamics...

# %%
max_creator = 5                             #Número máximo de autores que será considerado
n_article = len(abstracts)
creator_list = creator["Creator"].tolist() # Lista de Autores

# Criando um DataFrame para receber os pares de Autores que aparecem no mesmo artigo
# e o autor aleatório
test_corpus_creator = pd.DataFrame(columns=["Creator_1", "Creator_2", "Random_Creator"])

for article in abstracts.iterrows():  # Iterando sobre todos os artigos
    
    words = article[1]["Creator"]     # Célula do Dataframe onde se encontram os autores
    if words == []:                   # Se não houver keyword passa para próximo artigo
        pass
    
    else:
        for n in range(len(words)):   # Iterando sobre todos os autores de um artigo
            if n >= max_creator:      # Parar de iterar após o número máximo de autores
                break
            
            word_1 = words[n]         # Identificando primeiro autor
            
            # Como nem todos os autores estão na Lista de Autores é necessário 
            # verificar se word_1 está em creator_list 
            
            if word_1 in creator_list:
                for m in range(n+1, len(words)): # Iterando sobre os demais autores
                    if m >= max_creator:         # Parar de iterar após o número máximo de autores
                        break
                    
                    word_2 = words[m]            # Identificando segund0 autor
                    if word_2 in creator_list:
                        # Identificando autor aleatório
                        random_word = random.sample(creator_list, 1)[0]
                        # Adicionando os três autores no dataframe "test_corpus_creator"
                        test_corpus_creator.loc[len(test_corpus_creator)]= [word_1, word_2, random_word]

# %%
test_corpus_creator.to_csv("Test_Corpus_creator.csv")

# %%
test_corpus_creator
# Out:
#                      Creator_1                           Creator_2  \
# 0         bar-matthews, miryam                       ayalon, avner
# 1                   xing, lida                  lockley, martin g.
# 2                   xing, lida                      klein, hendrik
# 3           lockley, martin g.                      klein, hendrik
# 4            stenby, erling h.                        thomsen, kaj
# 5               marriner, nick                morhange, christophe
# 6                  loizeau, d.                         mangold, n.
# 7                  loizeau, d.                      bibring, j.-p.
# 8                  mangold, n.                      bibring, j.-p.
# 9              camin, federica                    larcher, roberto
# 10             camin, federica                      perini, matteo
# 11            larcher, roberto                      perini, matteo
# 12         anderson, robert f.                 fleisher, martin q.
# 13              franke, dieter                   pubellier, manuel
# 14             clift, peter d.                      carter, andrew
# 15            wilson, david j.                        galy, albert
# 16          christy, alfred a.                   kvalheim, olav m.
# 17            mastalerz, maria                 schimmelmann, arndt
# 18            giuliani, gaston                ohnenstetter, daniel
# 19            giuliani, gaston                 fallick, anthony e.
# 20            giuliani, gaston                       dubessy, jean
# 21        ohnenstetter, daniel                 fallick, anthony e.
# 22        ohnenstetter, daniel                       dubessy, jean
# 23         fallick, anthony e.                       dubessy, jean
# 24               knies, jochen                        ottesen, dag
# 25                  poulet, f.                      bibring, j.-p.
# 26          mattioli, emanuela                    olivier, nicolas
# 27          mattioli, emanuela                     pittet, bernard
# 28            olivier, nicolas                     pittet, bernard
# 29            storti, fabrizio                   balsamo, fabrizio
# ...                        ...                                 ...
# 26628        dieckmann, volker                    erdmann, michael
# 26629        dieckmann, volker                 galimberti, roberto
# 26630         horsfield, brian                    erdmann, michael
# 26631         horsfield, brian                 galimberti, roberto
# 26632         erdmann, michael                 galimberti, roberto
# 26633               schaap, m.                        cuvelier, c.
# 26634               schaap, m.                       bessagnet, b.
# 26635             cuvelier, c.                       bessagnet, b.
# 26636          braucher, régis                        calvet, marc
# 26637          braucher, régis                     bourlès, didier
# 26638             calvet, marc                     bourlès, didier
# 26639       anderson, brian j.                 collett, timothy s.
# 26640         herman, frédéric                           wang, wei
# 26641         kusakabe, minoru                       ohba, takeshi
# 26642          parize, olivier                       fiet, nicolas
# 26643          parize, olivier                   latil, jean-louis
# 26644            fiet, nicolas                   latil, jean-louis
# 26645           blanke, mogens                       imsland, lars
# 26646          maerten, frantz                    maerten, laurent
# 26647          maerten, frantz                       soliva, roger
# 26648         maerten, laurent                       soliva, roger
# 26649      schnetger, bernhard               brumsack, hans-jürgen
# 26650         do couto, damien             popescu, speranta-maria
# 26651         do couto, damien                    suc, jean-pierre
# 26652         do couto, damien  melinte-dobrinescu, mihaela carmen
# 26653  popescu, speranta-maria                    suc, jean-pierre
# 26654  popescu, speranta-maria  melinte-dobrinescu, mihaela carmen
# 26655         suc, jean-pierre  melinte-dobrinescu, mihaela carmen
# 26656      landing, william m.                 bruland, kenneth w.
# 26657      schaeffer, philippe                    albrecht, pierre
#
#                      Random_Creator
# 0                di primio, rolando
# 1                 feist, stephen w.
# 2                  burnham, alan k.
# 3                  palomera, isabel
# 4                   borgomano, jean
# 5                    hansen, pierre
# 6                     roveri, marco
# 7                          wang, h.
# 8                      tohver, eric
# 9                stockli, daniel f.
# 10                    lopez, michel
# 11                       zhang, qin
# 12                       franke, d.
# 13        kontogeorgis, georgios m.
# 14                    zakeri, arash
# 15                      lorenzo, e.
# 16                 pecoits, ernesto
# 17                 lorenz, ralph d.
# 18                     turcq, bruno
# 19            haszeldine, r. stuart
# 20               gattacceca, jérôme
# 21              achterberg, eric p.
# 22              galliéro, guillaume
# 23              wilkinson, angus j.
# 24                       masson, p.
# 25                  clague, john j.
# 26                  neubauer, franz
# 27                bruguier, olivier
# 28                caumon, guillaume
# 29                 thébaud, nicolas
# ...                             ...
# 26628               martin, paul j.
# 26629                   fouchet, t.
# 26630                      jin, min
# 26631          jaeger, jean-jacques
# 26632                       hu, bin
# 26633            sterpenich, jérôme
# 26634            masse, jean-pierre
# 26635                   li, xiaowei
# 26636              pironon, jacques
# 26637  frizon de lamotte, dominique
# 26638              lorenz, ralph d.
# 26639               saxena, nishank
# 26640                   serra, nuno
# 26641              joseph, philippe
# 26642            dantas, elton luiz
# 26643                   voisset, m.
# 26644                     leroy, s.
# 26645               alves, tiago m.
# 26646                  croot, peter
# 26647      andré-mayer, anne-sylvie
# 26648          pemberton, s. george
# 26649             libralato, simone
# 26650                     mille, g.
# 26651                 pauly, jérôme
# 26652                  lee, jong-mi
# 26653                 milne, angela
# 26654               randi, aurélien
# 26655           detournay, emmanuel
# 26656                     colas, f.
# 26657                    homola, p.
#
# [26658 rows x 3 columns]
